# %%
import pathlib

# %%
path = pathlib.Path(r'C:\Users\OU000150\OneDrive - HPE Automotores do Brasil Ltda')

for folder in ["Arquivos de Chat do Microsoft Teams", "Audios e Vídeos", "Códigos Fonte Área de Compras Mitsubishi", "Documentos e Apresentações/Apresentações", "Documentos e Apresentações/Documentos",  "Projetos"]:
    print(f"folder: {folder}")
    for child in (path / folder).iterdir():
        print(child.name)
        
for folder in [r"C:\Users\OU000150\Code", r"\\wsl.localhost\Ubuntu\home\gustavocb\Code"]:
    print(folder)
    for child in pathlib.Path(folder).iterdir():
        print(child.name)
# Out:
# folder: Arquivos de Chat do Microsoft Teams
# 123456132.pdf
# 14 1.jpg
# 14.jpg
# 93XTYKL1TSCR82693.pdf
# 93XTYKL1TSCR83068 1.pdf
# 93XTYKL1TSCR83068.pdf
# ff422b6a-affd-4f83-bac2-7fbdebe6f327.pdf
# final_text.txt
# gantt.html
# IMF.bat
# imf_report_example 1.pdf
# imf_report_example.pdf
# input 1.jpg
# input 2.jpg
# input.jpg
# Inspeção - Pontos de Solda.pdf
# Mapeamento de Cores.pptx
# Melhoria Contínua.pptx
# MVES standard 1.00.en.pt.docx
# MVES standard 1.00.en.pt.pdf
# output 1.jpg
# output 2.jpg
# output.jpg
# produced_vehicles.xlsx
# Relatório Completo Base de Dados de Reparo 1.mhtml
# Relatório Completo Base de Dados de Reparo.html
# Relatório Completo Base de Dados de Reparo.mhtml
# Requisição Formal de Compras Gamma APP.docx
# S-AVES manual for overseas 1.0(E).en.pt.docx
# S-AVES manual for overseas 1.0(E).en.pt.pdf
# Tabela Brunão.xlsx
# test.ipynb
# Utilizacao-de-IA-em-Visao-Computacional-para-Analise-de-Valor-Agregado-e-Yamazumi-na-HPE 1.pptx
# ...
