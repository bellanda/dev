# %%
import parsel

# %%
with open("./a.html", "r") as file:
    text = file.read()

selector = parsel.Selector(text)

[x for x in selector.xpath("//div//text()").getall() if x.strip() != ""]
# Out:
# ['Harry Potter',
#  'Criança dos anos 90',
#  'SoundCloud',
#  'Spa',
#  'Autocuidado',
#  'Heavy Metal',
#  'Festas em casa',
#  'Gin tônica',
#  'Ginástica',
#  'Hot Yoga',
#  'Meditação',
#  'Spotify',
#  'Sushi',
#  'Hóquei',
#  'Basquete',
#  'Batalha de poesia',
#  'Treino em casa',
#  'Teatro',
#  'De cafeteria em cafeteria',
#  'Visitar aquários',
#  'Tênis',
#  'Instagram',
#  'Fontes termais',
#  'Caminhada',
#  'Corrida',
#  'Viagem',
#  'Intercâmbio linguístico',
#  'Filmes',
#  'Guitarra',
#  'Desenvolvimento social',
#  'Academia',
#  'Redes sociais',
#  'Hip-hop',
#  'Skincare',
#  'J-Pop',
#  'Shisha',
#  'Críquete',
#  'Freelancer',
#  'Skate',
#  'Gospel',
#  'K-Pop',
#  'Fã de Harry Potter',
#  'Experimentar coisas novas',
#  'Fotografia',
#  'Bollywood',
#  'Leitura',
#  'Canto',
#  'Esportes',
#  'Poesia',
#  'Stand-up comedy',
#  'Café',
#  'Karaokê',
#  'Fortnite',
#  'Mergulho livre',
#  'Autodesenvolvimento',
#  'Conscientização sobre a saúde mental',
#  'Tour para foodies',
#  'Direitos dos Cidadãos',
#  'Jiu-jitsu',
#  'Mudança climática',
#  'Exposição',
#  'Passear com o cachorro',
#  'Direitos LGBTQIA+',
#  'Feminismo',
#  'VR Room',
#  'Escape Cafe',
#  'Compras',
#  'Brunch',
#  'Investimento',
#  'Jet ski',
#  'Reggaeton',
#  'Roupas de brechó',
#  'Vidas negras importam',
#  'Jogging',
#  'Viagens de carro',
#  'Moda vintage',
#  'Voguing',
#  'Couchsurfing',
#  'Happy hour',
#  'Inclusão',
#  'Sertanejo',
#  'Futebol americano',
#  'Patins inline',
#  'Investimentos',
#  'Tênis',
#  'Sorvete',
#  'Patinação no gelo',
#  'Direitos humanos',
#  'Exposições',
#  'Churrasco americano',
#  'Ski',
#  'Canoagem',
#  'Musicais do West End',
#  'Snowboard',
#  'Pilates',
#  'Pentatlo',
#  'Broadway',
#  'PlayStation',
#  'Cheerleading',
#  'Coral',
#  'Pole dance',
#  'Futsal',
#  'Corrida de carro',
#  'Pinterest',
#  'Pub Quiz',
#  'Festivais',
#  'Catan',
#  'Pisadinha',
#  'Cosplay',
#  'Esporte motorizado',
#  'Barraquinha de café',
#  'Criação de conteúdo',
#  'E-sports',
#  'Corrida de bicicleta',
#  'Maratonar séries',
#  'Composição musical',
#  'Bodycombat',
#  'Tatuagens',
#  'Pagode',
#  'Hiperativo(a)',
#  'Pintura',
#  'Bodyjam',
#  'Sextou',
#  'Stand Up Paddle',
#  'Padel',
#  'Blackpink',
#  'Surfe',
#  'Bruxaria',
#  'Boliche',
#  'Grime',
#  'Britpop dos anos 90',
#  'Brega Funk',
#  'Bodypump',
#  'Rolês',
#  'Bares de praia',
#  'Bodystep',
#  'Parapente',
#  'Upcycling',
#  'Igualdade',
#  'Astrologia',
#  'Motos',
#  'Hipismo',
#  'Empreendedorismo',
#  'Saquê',
#  'BTS',
#  'Cozinhar',
#  'Proteção ambiental',
#  'Esgrima',
#  'Futebol',
#  'Saxofone',
#  'Ficção científica',
#  'Dança',
#  'Festival de cinema',
#  'Jardinagem',
#  'Gastronomia',
#  'Intercâmbio',
#  'Sauna',
#  'Arte',
#  'Política',
#  'Flamenco',
#  'Museu',
#  'Ativismo',
#  'DAOs',
#  'Imóveis',
#  'Podcasts',
#  'Direitos de pessoas com deficiência',
#  'Rave',
#  'Pimms',
#  'Cinema drive-in',
#  'Escalada em rocha',
#  'Churrasco',
#  'Cerveja artesanal',
#  'Chá gelado',
#  'Bateria',
#  'Chá',
#  'Jogos de tabuleiro',
#  'Roblox',
#  'Pubs',
#  'Rock',
#  'Tango',
#  'Desenho',
#  'Trívia',
#  'Pho',
#  'Voluntariado',
#  'Meio ambiente',
#  'Patinação',
#  'Vinho',
#  'Dungeons & Dragons',
#  'Vlogs',
#  'Música eletrônica',
#  'Ramen',
#  'Levantamento de peso',
#  'Música ao vivo',
#  'Escrita',
#  'Xbox',
#  'Paz mundial',
#  'Luta livre',
#  'Literatura',
#  'Mangá',
#  'Pride',
#  'Maratona',
#  'Maquiagem',
#  'Empoderamento de jovens',
#  'YouTube',
#  'Artes marciais',
#  'Marvel',
#  'Luge',
#  'Hóquei no gelo',
#  'Taekwondo',
#  'Ginástica de trampolim',
#  'Polo Aquático',
#  'Ginástica rítmica',
#  'Culinária vegana',
#  'Remo',
#  'Vermute',
#  'Comida coreana',
#  'Tiro Esportivo',
#  'Twitter',
#  'Squash',
#  'Vôlei',
#  'Fazer tours a pé',
#  'Vinyasa',
#  'Realidade virtual',
#  'League of Legends',
#  'Karatê',
#  'Lacrosse',
#  'NFTs',
#  'Barzinhos',
#  'Nintendo',
#  'Beisebol',
#  'Festas',
#  'Balé',
#  'Banda',
#  'Jogos online',
#  'Battle Ground',
#  'Beach tennis',
#  'Sair à noite',
#  'Compras online',
#  'Velejar',
#  'Baixo',
#  'Home Broker',
#  'Forças armadas',
#  'Memes',
#  'Among Us',
#  'Corrida de moto',
#  'Muay Thai',
#  'Motociclismo',
#  'Metaverso',
#  'Mindfulness',
#  'Acapella',
#  'Instrumento musical',
#  'Galerias de arte',
#  'Escrita musical',
#  'Trilha',
#  'Ginástica artística',
#  'Montanhas',
#  'Arco e flecha',
#  'MPB',
#  'Atari',
#  'Mochilão',
#  'Pesca',
#  'Baladas',
#  'Comida de rua',
#  'Crossfit',
#  'Shows',
#  'Escalada',
#  'Fazer pães e bolos',
#  'Camping',
#  'Blogs',
#  'Colecionismo',
#  'Carros',
#  'Startup',
#  'Bubble Tea',
#  'Liga de basquete escolar ',
#  'Badminton',
#  'Estilo de vida ativo',
#  'Moda',
#  'Anime',
#  'NBA',
#  'MLB',
#  'Funk',
#  'Saltos Ornamentais',
#  'Caipirinha',
#  'Flag Football',
#  'Handebol',
#  'Nado artístico',
#  'Atletismo',
#  'Atividades em espaços fechados',
#  'Beisebol Softbol',
#  'Vôlei de praia',
#  'Tempeh',
#  'DIY',
#  'Festas populares',
#  'Ciclismo',
#  'Ar livre',
#  'TikTok',
#  'Piquenique',
#  'Twitch',
#  'Judô',
#  'Comédia',
#  'Trap',
#  'Música',
#  'Triatlo',
#  'Netflix',
#  'Disney',
#  'Big Brother Brasil',
#  'Rugby',
#  'Açaí',
#  'Samba',
#  'Tarô',
#  'Bolsa de valores',
#  'Ações',
#  'Natação',
#  'Tênis de mesa',
#  'Passar o tempo',
#  'Atividade física',
#  'Yoga',
#  'Filmes de terror',
#  'Boxe',
#  'Rolê no bar']

# %%
from PIL import Image

# %%
img = Image.open(r'C:\Users\OU000150\Code\exclude-from-compact\CV\assets\img\gustavo-social old.jpg')

# %%
img.resize((700, 800)).save(r'C:\Users\OU000150\Code\exclude-from-compact\CV\assets\img\gustavo-social.jpg')
